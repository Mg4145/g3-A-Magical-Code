# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from statistics import mean

# %%
#  The convention for naming of csv files is 
# "results_group#_domain#_batch#_nvalue.csv"

# %%
def get_null_values(group, domain):
    null_avg = []
    for i in range(10, 110, 10): 
        file_path = "results/results_" + group + "_" + domain + "_" + str(i) + ".csv"
        null_avg.append(round(pd.read_csv(file_path)['score'].mean() * 100, 2))
    return null_avg

# %%
g1_null = get_null_values("1", "nulls")
g2_null = get_null_values("2", "nulls")
g3_null = get_null_values("3", "nulls")
g4_null = get_null_values("4", "nulls")
g5_null = get_null_values("5", "nulls")
g6_null = get_null_values("6", "nulls")
g7_null = get_null_values("7", "nulls")
g8_null = get_null_values("8", "nulls")

n_values = list(range(10, 110, 10))

g1_avg_null = mean(g1_null)
g2_avg_null = mean(g2_null)
g3_avg_null = mean(g3_null)
g4_avg_null = mean(g4_null)
g5_avg_null = mean(g5_null)
g6_avg_null = mean(g6_null)
g7_avg_null = mean(g7_null)
g8_avg_null = mean(g8_null)

null_avg = []
null_avg.append(g1_avg_null)
null_avg.append(g2_avg_null)
null_avg.append(g3_avg_null)
null_avg.append(g4_avg_null)
null_avg.append(g5_avg_null)
null_avg.append(g6_avg_null)
null_avg.append(g7_avg_null)
null_avg.append(g8_avg_null)

# %%
# Plot values
n_values = list(range(10, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n - values")
plt.ylabel("Percentage")
plt.title("All Group's Null Percentage for n-Values")

plt.plot(n_values, g1_null, label = "Group 1")
plt.plot(n_values, g2_null, label = "Group 2")
plt.plot(n_values, g3_null, label = "Group 3")
plt.plot(n_values, g4_null, label = "Group 4")
plt.plot(n_values, g5_null, label = "Group 5")
plt.plot(n_values, g6_null, label = "Group 6")
plt.plot(n_values, g7_null, label = "Group 7")
plt.plot(n_values, g8_null, label = "Group 8")

plt.xticks(n_values)
# plt.yticks()

plt.legend()
plt.show()

# %%
# Plot values
n_values = list(range(10, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(15, 10))
plt.xlabel("Groups")
plt.ylabel("Percentage")
plt.title("All Group's Mean Null Percentage for n-Values")

plt.bar(groups, null_avg, color = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray'])

plt.xticks(groups)
# plt.yticks()

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def get_scores(group, batch):
    total_domain_scores = [] # [domain1, domain2, domain3, ... domain8]
    for domain in range(1, 9):
        n_sum = [] # n = 0, 10, 20, ... , 100
        for n in range(0, 110, 10): 
            file_path = "results/results_" + group + "_" + str(domain) + "_" + batch + "_" + str(n) + ".csv"
            try:
                pd.read_csv(file_path)
            except:
                print(f"{file_path}\t File Not Found")
            else: 
                n_sum.append(pd.read_csv(file_path)['score'].sum())
        total_domain_scores.append(round(sum(n_sum), 2))
    return total_domain_scores

# %%
g1_avg_domain = get_scores("1", "2")
g2_avg_domain = get_scores("2", "2")
g3_avg_domain = get_scores("3", "2")
g4_avg_domain = get_scores("4", "2")
g5_avg_domain = get_scores("5", "2")
g6_avg_domain = get_scores("6", "1")
g7_avg_domain = get_scores("7", "1")
g8_avg_domain = get_scores("8", "2")
# Out:
# results/results_6_5_1_100.csv	 File Not Found
# results/results_6_6_1_0.csv	 File Not Found
# results/results_6_6_1_10.csv	 File Not Found
# results/results_6_6_1_20.csv	 File Not Found
# results/results_6_6_1_30.csv	 File Not Found
# results/results_6_6_1_40.csv	 File Not Found
# results/results_6_6_1_50.csv	 File Not Found
# results/results_6_6_1_60.csv	 File Not Found
# results/results_6_6_1_70.csv	 File Not Found
# results/results_6_6_1_80.csv	 File Not Found
# results/results_6_6_1_90.csv	 File Not Found
# results/results_6_6_1_100.csv	 File Not Found
# results/results_6_7_1_0.csv	 File Not Found
# results/results_6_7_1_10.csv	 File Not Found
# results/results_6_7_1_20.csv	 File Not Found
# results/results_6_7_1_30.csv	 File Not Found
# results/results_6_7_1_40.csv	 File Not Found
# results/results_6_7_1_50.csv	 File Not Found
# results/results_6_7_1_60.csv	 File Not Found
# results/results_6_7_1_70.csv	 File Not Found
# results/results_6_7_1_80.csv	 File Not Found
# ...

# %%
n_values = list(range(10, 110, 10))
groups = list(range(1, 9))

domains = [
"Alphanumeric",
"Airport Codes",
"Passwords",
"Latitude & Longitude",
"Addresses",
"War Sentences",
"Longer Sentences & Words",
"People & Places"
]

plt.figure(figsize=(10, 10))
plt.xlabel("Domain")
plt.ylabel("Scores")
plt.title("Overall Scores for All Shuffles and Domains For All Groups")

plt.plot(domains, g1_avg_domain, label = "Group 1")
plt.plot(domains, g2_avg_domain, label = "Group 2")
plt.plot(domains, g3_avg_domain, label = "Group 3")
plt.plot(domains, g4_avg_domain, label = "Group 4")
plt.plot(domains, g5_avg_domain, label = "Group 5")
plt.plot(domains, g6_avg_domain, label = "Group 6")
plt.plot(domains, g7_avg_domain, label = "Group 7")
plt.plot(domains, g8_avg_domain, label = "Group 8")

plt.scatter(domains, g1_avg_domain)
plt.scatter(domains, g2_avg_domain)
plt.scatter(domains, g3_avg_domain)
plt.scatter(domains, g4_avg_domain)
plt.scatter(domains, g5_avg_domain)
plt.scatter(domains, g6_avg_domain)
plt.scatter(domains, g7_avg_domain)
plt.scatter(domains, g8_avg_domain)

plt.xticks(domains)
plt.xticks(rotation=90)
# plt.yticks(n_values)

plt.legend()
plt.show()

# %%
domains = [
"Alphanumeric",
"Airport Codes", 
"Flight Numbers, and Dates",
"Passwords",
"Latitude and Longitude",
"Addresses",
"War Sentences",
"Longer Sentences, Words, and Coordinates",
"Names of People and Places"
]

# %%
def get_domain_scores(group, domain, batch):
    domain_scores = []
    for n in range(0, 110, 10): 
        file_path = "results/results_" + group + "_" + str(domain) + "_" + batch + "_" + str(n) + ".csv"
        try:
            pd.read_csv(file_path)
        except:
            print(f"{file_path}\t File Not Found")
            domain_scores.append(0)
        else: 
#             df = pd.read_csv(file_path)
#             print(df['score'].sum())
            domain_scores.append(round(pd.read_csv(file_path)['score'].sum(), 2))
            
    return domain_scores

# %%
g1_1_scores = get_domain_scores("1", "1", "2")
g2_1_scores = get_domain_scores("2", "1", "2")
g3_1_scores = get_domain_scores("3", "1", "2")
g4_1_scores = get_domain_scores("4", "1", "2")
g5_1_scores = get_domain_scores("5", "1", "2")
g6_1_scores = get_domain_scores("6", "1", "1")
g7_1_scores = get_domain_scores("7", "1", "1")
g8_1_scores = get_domain_scores("8", "1", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Alphanumeric Domain for Number of n Shuffles")

plt.plot(n_values, g1_1_scores, label = "Group 1")
plt.plot(n_values, g2_1_scores, label = "Group 2")
plt.plot(n_values, g3_1_scores, label = "Group 3")
plt.plot(n_values, g4_1_scores, label = "Group 4")
plt.plot(n_values, g5_1_scores, label = "Group 5")
plt.plot(n_values, g6_1_scores, label = "Group 6")
plt.plot(n_values, g7_1_scores, label = "Group 7")
plt.plot(n_values, g8_1_scores, label = "Group 8")

plt.scatter(n_values, g1_1_scores)
plt.scatter(n_values, g2_1_scores)
plt.scatter(n_values, g3_1_scores)
plt.scatter(n_values, g4_1_scores)
plt.scatter(n_values, g5_1_scores)
plt.scatter(n_values, g6_1_scores)
plt.scatter(n_values, g7_1_scores)
plt.scatter(n_values, g8_1_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()

# %%
g1_2_scores = get_domain_scores("1", "2", "2")
g2_2_scores = get_domain_scores("2", "2", "2")
g3_2_scores = get_domain_scores("3", "2", "2")
g4_2_scores = get_domain_scores("4", "2", "2")
g5_2_scores = get_domain_scores("5", "2", "2")
g6_2_scores = get_domain_scores("6", "2", "1")
g7_2_scores = get_domain_scores("7", "2", "1")
g8_2_scores = get_domain_scores("8", "2", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Airport Codes Domain for Number of n Shuffles")

plt.plot(n_values, g1_2_scores, label = "Group 1")
plt.plot(n_values, g2_2_scores, label = "Group 2")
plt.plot(n_values, g3_2_scores, label = "Group 3")
plt.plot(n_values, g4_2_scores, label = "Group 4")
plt.plot(n_values, g5_2_scores, label = "Group 5")
plt.plot(n_values, g6_2_scores, label = "Group 6")
plt.plot(n_values, g7_2_scores, label = "Group 7")
plt.plot(n_values, g8_2_scores, label = "Group 8")

plt.scatter(n_values, g1_2_scores)
plt.scatter(n_values, g2_2_scores)
plt.scatter(n_values, g3_2_scores)
plt.scatter(n_values, g4_2_scores)
plt.scatter(n_values, g5_2_scores)
plt.scatter(n_values, g6_2_scores)
plt.scatter(n_values, g7_2_scores)
plt.scatter(n_values, g8_2_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()

# %%
g1_3_scores = get_domain_scores("1", "3", "2")
g2_3_scores = get_domain_scores("2", "3", "2")
g3_3_scores = get_domain_scores("3", "3", "2")
g4_3_scores = get_domain_scores("4", "3", "2")
g5_3_scores = get_domain_scores("5", "3", "2")
g6_3_scores = get_domain_scores("6", "3", "1")
g7_3_scores = get_domain_scores("7", "3", "1")
g8_3_scores = get_domain_scores("8", "3", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Passwords Domain for Number of n Shuffles")

plt.plot(n_values, g1_3_scores, label = "Group 1")
plt.plot(n_values, g2_3_scores, label = "Group 2")
plt.plot(n_values, g3_3_scores, label = "Group 3")
plt.plot(n_values, g4_3_scores, label = "Group 4")
plt.plot(n_values, g5_3_scores, label = "Group 5")
plt.plot(n_values, g6_3_scores, label = "Group 6")
plt.plot(n_values, g7_3_scores, label = "Group 7")
plt.plot(n_values, g8_3_scores, label = "Group 8")

plt.scatter(n_values, g1_3_scores)
plt.scatter(n_values, g2_3_scores)
plt.scatter(n_values, g3_3_scores)
plt.scatter(n_values, g4_3_scores)
plt.scatter(n_values, g5_3_scores)
plt.scatter(n_values, g6_3_scores)
plt.scatter(n_values, g7_3_scores)
plt.scatter(n_values, g8_3_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()

# %%
g1_4_scores = get_domain_scores("1", "4", "2")
g2_4_scores = get_domain_scores("2", "4", "2")
g3_4_scores = get_domain_scores("3", "4", "2")
g4_4_scores = get_domain_scores("4", "4", "2")
g5_4_scores = get_domain_scores("5", "4", "2")
g6_4_scores = get_domain_scores("6", "4", "1")
g7_4_scores = get_domain_scores("7", "4", "1")
g8_4_scores = get_domain_scores("8", "4", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Latitude/Longitude Domain for Number of n Shuffles")

plt.plot(n_values, g1_4_scores, label = "Group 1")
plt.plot(n_values, g2_4_scores, label = "Group 2")
plt.plot(n_values, g3_4_scores, label = "Group 3")
plt.plot(n_values, g4_4_scores, label = "Group 4")
plt.plot(n_values, g5_4_scores, label = "Group 5")
plt.plot(n_values, g6_4_scores, label = "Group 6")
plt.plot(n_values, g7_4_scores, label = "Group 7")
plt.plot(n_values, g8_4_scores, label = "Group 8")

plt.scatter(n_values, g1_4_scores)
plt.scatter(n_values, g2_4_scores)
plt.scatter(n_values, g3_4_scores)
plt.scatter(n_values, g4_4_scores)
plt.scatter(n_values, g5_4_scores)
plt.scatter(n_values, g6_4_scores)
plt.scatter(n_values, g7_4_scores)
plt.scatter(n_values, g8_4_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()

# %%
g1_5_scores = get_domain_scores("1", "5", "2")
g2_5_scores = get_domain_scores("2", "5", "2")
g3_5_scores = get_domain_scores("3", "5", "2")
g4_5_scores = get_domain_scores("4", "5", "2")
g5_5_scores = get_domain_scores("5", "5", "2")
g6_5_scores = get_domain_scores("6", "5", "1")
g7_5_scores = get_domain_scores("7", "5", "1")
g8_5_scores = get_domain_scores("8", "5", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Addresses Domain for Number of n Shuffles")

plt.plot(n_values, g1_5_scores, label = "Group 1")
plt.plot(n_values, g2_5_scores, label = "Group 2")
plt.plot(n_values, g3_5_scores, label = "Group 3")
plt.plot(n_values, g4_5_scores, label = "Group 4")
plt.plot(n_values, g5_5_scores, label = "Group 5")
plt.plot(n_values, g6_5_scores, label = "Group 6")
plt.plot(n_values, g7_5_scores, label = "Group 7")
plt.plot(n_values, g8_5_scores, label = "Group 8")

plt.scatter(n_values, g1_5_scores)
plt.scatter(n_values, g2_5_scores)
plt.scatter(n_values, g3_5_scores)
plt.scatter(n_values, g4_5_scores)
plt.scatter(n_values, g5_5_scores)
plt.scatter(n_values, g6_5_scores)
plt.scatter(n_values, g7_5_scores)
plt.scatter(n_values, g8_5_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()
# Out:
# results/results_6_5_1_100.csv	 File Not Found

# %%
g1_6_scores = get_domain_scores("1", "6", "2")
g2_6_scores = get_domain_scores("2", "6", "2")
g3_6_scores = get_domain_scores("3", "6", "2")
g4_6_scores = get_domain_scores("4", "6", "2")
g5_6_scores = get_domain_scores("5", "6", "2")
g6_6_scores = get_domain_scores("6", "6", "1")
g7_6_scores = get_domain_scores("7", "6", "1")
g8_6_scores = get_domain_scores("8", "6", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for War Sentences Domain for Number of n Shuffles")

plt.plot(n_values, g1_6_scores, label = "Group 1")
plt.plot(n_values, g2_6_scores, label = "Group 2")
plt.plot(n_values, g3_6_scores, label = "Group 3")
plt.plot(n_values, g4_6_scores, label = "Group 4")
plt.plot(n_values, g5_6_scores, label = "Group 5")
plt.plot(n_values, g6_6_scores, label = "Group 6")
plt.plot(n_values, g7_6_scores, label = "Group 7")
plt.plot(n_values, g8_6_scores, label = "Group 8")

plt.scatter(n_values, g1_6_scores)
plt.scatter(n_values, g2_6_scores)
plt.scatter(n_values, g3_6_scores)
plt.scatter(n_values, g4_6_scores)
plt.scatter(n_values, g5_6_scores)
plt.scatter(n_values, g6_6_scores)
plt.scatter(n_values, g7_6_scores)
plt.scatter(n_values, g8_6_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()
# Out:
# results/results_6_6_1_0.csv	 File Not Found
# results/results_6_6_1_10.csv	 File Not Found
# results/results_6_6_1_20.csv	 File Not Found
# results/results_6_6_1_30.csv	 File Not Found
# results/results_6_6_1_40.csv	 File Not Found
# results/results_6_6_1_50.csv	 File Not Found
# results/results_6_6_1_60.csv	 File Not Found
# results/results_6_6_1_70.csv	 File Not Found
# results/results_6_6_1_80.csv	 File Not Found
# results/results_6_6_1_90.csv	 File Not Found
# results/results_6_6_1_100.csv	 File Not Found

# %%
g1_7_scores = get_domain_scores("1", "7", "2")
g2_7_scores = get_domain_scores("2", "7", "2")
g3_7_scores = get_domain_scores("3", "7", "2")
g4_7_scores = get_domain_scores("4", "7", "2")
g5_7_scores = get_domain_scores("5", "7", "2")
g6_7_scores = get_domain_scores("6", "7", "1")
g7_7_scores = get_domain_scores("7", "7", "1")
g8_7_scores = get_domain_scores("8", "7", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Longer Sentences and Words Domain for Number of n Shuffles")

plt.plot(n_values, g1_7_scores, label = "Group 1")
plt.plot(n_values, g2_7_scores, label = "Group 2")
plt.plot(n_values, g3_7_scores, label = "Group 3")
plt.plot(n_values, g4_7_scores, label = "Group 4")
plt.plot(n_values, g5_7_scores, label = "Group 5")
plt.plot(n_values, g6_7_scores, label = "Group 6")
plt.plot(n_values, g7_7_scores, label = "Group 7")
plt.plot(n_values, g8_7_scores, label = "Group 8")

plt.scatter(n_values, g1_7_scores)
plt.scatter(n_values, g2_7_scores)
plt.scatter(n_values, g3_7_scores)
plt.scatter(n_values, g4_7_scores)
plt.scatter(n_values, g5_7_scores)
plt.scatter(n_values, g6_7_scores)
plt.scatter(n_values, g7_7_scores)
plt.scatter(n_values, g8_7_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()
# Out:
# results/results_6_7_1_0.csv	 File Not Found
# results/results_6_7_1_10.csv	 File Not Found
# results/results_6_7_1_20.csv	 File Not Found
# results/results_6_7_1_30.csv	 File Not Found
# results/results_6_7_1_40.csv	 File Not Found
# results/results_6_7_1_50.csv	 File Not Found
# results/results_6_7_1_60.csv	 File Not Found
# results/results_6_7_1_70.csv	 File Not Found
# results/results_6_7_1_80.csv	 File Not Found
# results/results_6_7_1_90.csv	 File Not Found
# results/results_6_7_1_100.csv	 File Not Found

# %%
g1_8_scores = get_domain_scores("1", "8", "2")
g2_8_scores = get_domain_scores("2", "8", "2")
g3_8_scores = get_domain_scores("3", "8", "2")
g4_8_scores = get_domain_scores("4", "8", "2")
g5_8_scores = get_domain_scores("5", "8", "2")
g6_8_scores = get_domain_scores("6", "8", "1")
g7_8_scores = get_domain_scores("7", "8", "1")
g8_8_scores = get_domain_scores("8", "8", "2")

n_values = list(range(0, 110, 10))
groups = list(range(1, 9))

plt.figure(figsize=(10, 10))
plt.xlabel("n-values")
plt.ylabel("Scores")
plt.title("Scores for Names of People and Places Domain for Number of n Shuffles")

plt.plot(n_values, g1_8_scores, label = "Group 1")
plt.plot(n_values, g2_8_scores, label = "Group 2")
plt.plot(n_values, g3_8_scores, label = "Group 3")
plt.plot(n_values, g4_8_scores, label = "Group 4")
plt.plot(n_values, g5_8_scores, label = "Group 5")
plt.plot(n_values, g6_8_scores, label = "Group 6")
plt.plot(n_values, g7_8_scores, label = "Group 7")
plt.plot(n_values, g8_8_scores, label = "Group 8")

plt.scatter(n_values, g1_8_scores)
plt.scatter(n_values, g2_8_scores)
plt.scatter(n_values, g3_8_scores)
plt.scatter(n_values, g4_8_scores)
plt.scatter(n_values, g5_8_scores)
plt.scatter(n_values, g6_8_scores)
plt.scatter(n_values, g7_8_scores)
plt.scatter(n_values, g8_8_scores)

plt.xticks(n_values)
# plt.yticks(n_values)

plt.legend()
plt.show()
# Out:
# results/results_6_8_1_0.csv	 File Not Found
# results/results_6_8_1_10.csv	 File Not Found
# results/results_6_8_1_20.csv	 File Not Found
# results/results_6_8_1_30.csv	 File Not Found
# results/results_6_8_1_40.csv	 File Not Found
# results/results_6_8_1_50.csv	 File Not Found
# results/results_6_8_1_60.csv	 File Not Found
# results/results_6_8_1_70.csv	 File Not Found
# results/results_6_8_1_80.csv	 File Not Found
# results/results_6_8_1_90.csv	 File Not Found
# results/results_6_8_1_100.csv	 File Not Found
